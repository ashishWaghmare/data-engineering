# %% [markdown]
# # Hello
# This is my first notebook to start working on data science

# %%
"Hello World"
# Out:
# 'Hello World'

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(range(20))
